# %%
import tweepy
import json
import pandas as pd
from dotenv import load_dotenv
import os

# %%
load_dotenv()
api_key = os.getenv("API_KEY")
api_key_secret = os.getenv("API_KEY_SECRET")
bearer_token = os.getenv("BEARER_TOKEN")
access_token = os.getenv("ACCESS_TOKEN")
access_token_secret = os.getenv("ACCESS_TOKEN_SECRET")
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")

# %%
print(api_key, api_key_secret)
# Out:
# 73yrv7gdi3NWUFDaoq79P6i26 3EH7pIztp3vOiWfGxz5slcHMsj2LHHK38ifOeEUpPMZJm06Jlc

# %%
tweepy_auth = tweepy.OAuthHandler(api_key, api_key_secret)
tweepy_auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(tweepy_auth)

# Get the user object for the authenticated user)
api.search_tweets(q="python", lang="en", count=10, tweet_mode="extended")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[22], line 6
#       3 api = tweepy.API(tweepy_auth)
#       5 # Get the user object for the authenticated user)
# ----> 6 api.search_tweets(q="python", lang="en", count=10, tweet_mode="extended")
#
# File d:\LEARN\SCRAPPING META\.venv\Lib\site-packages\tweepy\api.py:33, in pagination.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      31 @functools.wraps(method)
#      32 def wrapper(*args, **kwargs):
# ---> 33     return method(*args, **kwargs)
#
# File d:\LEARN\SCRAPPING META\.venv\Lib\site-packages\tweepy\api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      44 kwargs['payload_list'] = payload_list
#      45 kwargs['payload_type'] = payload_type
# ---> 46 return method(*args, **kwargs)
#
# ...

# %%
# Out:
# AAAAAAAAAAAAAAAAAAAAADQQlQEAAAAAsV3YetEWiZ6rQQRcBGeaSvpgsE0%3DhIFjLZIuNQjzwsUXSAbJdHT1nPuPWxNNMzDflaHojt455Nt0XV

# %%
client = tweepy.Client(bearer_token=bearer_token)

query = "e commerce"
tweets = client.search_recent_tweets(query=query, max_results=10)
print(tweets)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 client = tweepy.Client(bearer_token=bearer_token)
#       3 query = "e commerce"
# ----> 4 tweets = client.search_recent_tweets(query=query, max_results=10)
#       5 print(tweets)
#
# File d:\LEARN\SCRAPPING META\.venv\Lib\site-packages\tweepy\client.py:1266, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1174 """search_recent_tweets( \
#    1175     query, *, end_time=None, expansions=None, max_results=None, \
#    1176     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1263 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1264 """
#    1265 params["query"] = query
# -> 1266 return self._make_request(
#    1267     "GET", "/2/tweets/search/recent", params=params,
#    1268     endpoint_parameters=(
# ...

# %%
import requests

# Langkah 1: Mendapatkan semua kode dari hasil respon pertama
url_hashtag = "https://instagram-scraper-api2.p.rapidapi.com/v1/hashtag"
querystring_hashtag = {"hashtag":"ecommerce"}

headers = {
    "x-rapidapi-key": "a8c4ed5b7dmsh9810575efeb725fp186d0ajsn0875bf677f8b",
    "x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response_hashtag = requests.get(url_hashtag, headers=headers, params=querystring_hashtag)

# Menyimpan hasil respon ke dalam dictionary
response_data = response_hashtag.json()
print(response_data)

# Mengambil data pada 'items' dan menyimpan yang berisi 'code'
# Fixed: Ensure 'items' is a key in the response and it contains a list of dictionaries before proceeding.
if 'items' in response_data and isinstance(response_data['items'], list):
    items_data_with_code = [item['code'] for item in response_data['items'] if 'code' in item]
    print(items_data_with_code)
else:
    print("No 'items' found or 'items' is not a list.")

# Langkah 2: Menggunakan setiap kode sebagai parameter untuk mendapatkan komentar
url_comments = "https://instagram-scraper-api2.p.rapidapi.com/v1/comments"
headers = {
    "x-rapidapi-key": "a8c4ed5b7dmsh9810575efeb725fp186d0ajsn0875bf677f8b",
    "x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

for code in items_data_with_code:
    querystring_comments = {"code_or_id_or_url": code}
    response_comments = requests.get(url_comments, headers=headers, params=querystring_comments)
    comments_data = response_comments.json()
    print(f"Comments for code {code}:")
    print(comments_data)
# Out:
# {'data': {'additional_data': {'allow_following': 1, 'allow_muting_story': True, 'content_advisory': None, 'follow_button_text': None, 'formatted_media_count': '16.7M', 'fresh_topic_metadata': None, 'hide_use_hashtag_button': False, 'id': 17843796520062161, 'is_trending': False, 'media_count': 16784608, 'name': 'ecommerce', 'non_violating': 1, 'profile_pic_url': 'https://instagram.fdub6-1.fna.fbcdn.net/v/t39.30808-6/449120821_18013639220454434_8634506981273052153_n.jpg?stp=dst-jpg_e35_p640x640_sh0.08&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDA2eDE3NTguc2RyLmYzMDgwOCJ9&_nc_ht=instagram.fdub6-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=1dANxI7iyxYQ7kNvgE_1REH&edm=AGyKU4gAAAAA&ccb=7-5&ig_cache_key=MzM5NzM4OTE5NDUwOTgyNjI3Nw%3D%3D.2-ccb7-5&oh=00_AYCjPp9-fCAk_5WHduwFfrgzfOHbSxBFOKNGHKesXx-OuA&oe=6684330F&_nc_sid=2011ad', 'promo_banner': None, 'related_tags': None, 'show_follow_drop_down': False, 'social_context': '', 'social_context_profile_links': [], 'status': 'ok', 'subtitle': 'See a few to
# ...
